# %%
import pandas as pd
import numpy as np
import seaborn as sns
import  matplotlib.pyplot as plt

# %%
data = pd.read_csv("Housing.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace= True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop(['median_house_value'], axis = 1)
y = data['median_house_value']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
train_data = X_train.join(y_train)
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6074     -117.86     34.08                31.0       2524.0           349.0
# 10626    -117.77     33.71                13.0       1939.0           247.0
# 5459     -118.47     33.99                34.0       1875.0           501.0
# 20334    -119.01     34.23                11.0       5785.0          1035.0
# 11379    -117.95     33.68                26.0       2249.0           344.0
# ...          ...       ...                 ...          ...             ...
# 3207     -119.63     36.34                26.0       1463.0           261.0
# 18399    -121.76     37.23                16.0       4274.0           715.0
# 19509    -121.02     37.64                42.0       1437.0           307.0
# 14923    -117.06     32.64                30.0       4494.0           667.0
# 10137    -117.89     33.91                33.0       1264.0           224.0
#
#        population  households  median_income ocean_proximity  \
# 6074       1003.0       343.0         7.5196       <1H OCEAN
# 10626       928.0       244.0         8.1111       <1H OCEAN
# 5459       1491.0       526.0         2.8417       <1H OCEAN
# 20334      2760.0       985.0         4.6930       <1H OCEAN
# 11379      1311.0       373.0         5.0287       <1H OCEAN
# ...           ...         ...            ...             ...
# 3207        699.0       219.0         3.5536          INLAND
# 18399      2240.0       704.0         5.4218       <1H OCEAN
# 19509      1035.0       284.0         2.1036          INLAND
# 14923      1883.0       680.0         5.7660      NEAR OCEAN
# 10137       527.0       227.0         3.7321       <1H OCEAN
#
#        median_house_value
# 6074             380900.0
# 10626            379800.0
# 5459             321400.0
# 20334            232200.0
# 11379            265000.0
# ...                   ...
# 3207              71400.0
# 18399            233900.0
# 19509             88300.0
# 14923            186100.0
# 10137            216500.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(train_data.corr(numeric_only = True), annot = True)
# Out:
# <Axes: >

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms']) +1
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms']) +1
train_data['population'] = np.log(train_data['population']) +1
train_data['households'] = np.log(train_data['households']) +1

# %%
train_data.hist(figsize= (15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
#train_data.ocean_proximity.value_counts()
print(train_data.columns)
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', '<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY',
#        'NEAR OCEAN'],
#       dtype='object')

# %%
#one hot encoding

# %%
#joining data
train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/cx/w4y6syy51yn0y9858lpwy0jh0000gn/T/ipykernel_36049/2894965977.py in ?()
#       1 #joining data
# ----> 2 train_data = train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'], axis = 1)
#
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ocean_proximity'

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6074     -117.86     34.08                31.0     8.833600        6.855072
# 10626    -117.77     33.71                13.0     8.569928        6.509388
# 5459     -118.47     33.99                34.0     8.536364        7.216606
# 20334    -119.01     34.23                11.0     9.663024        7.942157
# 11379    -117.95     33.68                26.0     8.718241        6.840642
# ...          ...       ...                 ...          ...             ...
# 3207     -119.63     36.34                26.0     8.288244        6.564520
# 18399    -121.76     37.23                16.0     9.360305        7.572283
# 19509    -121.02     37.64                42.0     8.270313        6.726848
# 14923    -117.06     32.64                30.0     9.410498        7.502790
# 10137    -117.89     33.91                33.0     8.142037        6.411646
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 6074     7.910751    6.837730         7.5196            380900.0       True
# 10626    7.833032    6.497168         8.1111            379800.0       True
# 5459     8.307202    7.265301         2.8417            321400.0       True
# 20334    8.922986    7.892642         4.6930            232200.0       True
# 11379    8.178545    6.921578         5.0287            265000.0       True
# ...           ...         ...            ...                 ...        ...
# 3207     7.549651    6.389072         3.5536             71400.0      False
# 18399    8.714231    7.556778         5.4218            233900.0       True
# 19509    7.942157    6.648974         2.1036             88300.0      False
# 14923    8.540622    7.522093         5.7660            186100.0      False
# 10137    7.267201    6.424950         3.7321            216500.0       True
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 6074    False   False     False       False
# 10626   False   False     False       False
# 5459    False   False     False       False
# 20334   False   False     False       False
# 11379   False   False     False       False
# ...       ...     ...       ...         ...
# 3207     True   False     False       False
# 18399   False   False     False       False
# 19509    True   False     False       False
# 14923   False   False     False        True
# 10137   False   False     False       False
#
# [16346 rows x 14 columns]

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(train_data.corr(numeric_only = True), annot = True, cmap="turbo")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x = 'latitude', y= 'longitude', data= train_data, hue="median_house_value", palette= "coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedroom_ratio'] = train_data['total_rooms'] / train_data['total_bedrooms']
train_data['household_rooms'] = train_data['total_rooms'] / train_data['total_households']

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(train_data.corr(numeric_only = True), annot = True, cmap="turbo")
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression

X_train, y_train = train_data.drop(['median_house_value'], axis=1) , train_data['median_house_value']
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()
